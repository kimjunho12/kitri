# %%
import pandas as pd

# 딕셔너리 선언
excel_exam_data1 = {
    '학생' : ['최원석', '류건혁', '최난', '유혜미', '정현우']
}

# %%
import pandas as pd

# 딕셔너리 선언
excel_exam_data1 = {
    '학생' : ['최원석', '류건혁', '최난', '유혜미', '정현우'],
    '국어' : [100] * 5,
    '영어' : [90] * 5,
    '수학' : [80] * 5,
    '과학' : [70] * 5
}

# %%
excel_exam_data1['국어']
# Out:
# [100, 100, 100, 100, 100]

# %%
excel_exam_data1
# Out:
# {'학생': ['최원석', '류건혁', '최난', '유혜미', '정현우'],
#  '국어': [100, 100, 100, 100, 100],
#  '영어': [90, 90, 90, 90, 90],
#  '수학': [80, 80, 80, 80, 80],
#  '과학': [70, 70, 70, 70, 70]}

# %%
print(excel_exam_data1)
# Out:
# {'학생': ['최원석', '류건혁', '최난', '유혜미', '정현우'], '국어': [100, 100, 100, 100, 100], '영어': [90, 90, 90, 90, 90], '수학': [80, 80, 80, 80, 80], '과학': [70, 70, 70, 70, 70]}

# %%
df = pd.DataFrame(excel_exam_data1)

# %%
df
# Out:
#     학생   국어  영어  수학  과학
# 0  최원석  100  90  80  70
# 1  류건혁  100  90  80  70
# 2   최난  100  90  80  70
# 3  유혜미  100  90  80  70
# 4  정현우  100  90  80  70

# %%
df = pd.DataFrame(excel_exam_data1)

# %%
df = pd.DataFrame(excel_exam_data1)
# 판다스의 자료형
# - 시리즈(Series) : 1차원 데이터 --> 행 또는 열이 1개뿐인 데이터

# %%
# - 시리즈(Series) : 1차원 데이터 --> 행 또는 열이 1개뿐인 데이터
# - 데이터프레임(Dataframe) : 다차원 데이터

# %%
excel_exam_data1.keys
# Out:
# <function dict.keys>

# %%
excel_exam_data1.keys()
# Out:
# dict_keys(['학생', '국어', '영어', '수학', '과학'])

# %%
df = pd.DataFrame(excel_exam_data1, excel_exam_data1.keys())

# %%
df
# Out:
#      학생   국어  영어  수학  과학
# 학생  최원석  100  90  80  70
# 국어  류건혁  100  90  80  70
# 영어   최난  100  90  80  70
# 수학  유혜미  100  90  80  70
# 과학  정현우  100  90  80  70

# %%
df = pd.DataFrame(excel_exam_data1,)

# %%
# 판다스의 자료형
# - 시리즈(Series) : 1차원 데이터 --> 행 또는 열이 1개뿐인 데이터
# - 데이터프레임(Dataframe) : 다차원 데이터

# %%
df
# Out:
#     학생   국어  영어  수학  과학
# 0  최원석  100  90  80  70
# 1  류건혁  100  90  80  70
# 2   최난  100  90  80  70
# 3  유혜미  100  90  80  70
# 4  정현우  100  90  80  70

# %%
excel_writer = pd.ExcelWriter('./data/학생시험성적.xlsx', engine='xlsxwriter')

# %%
df.to_excel(excel_writer, index=False)
excel_writer.save()

# %%
df = pd.DataFrame(excel_exam_data1,)
df.to_excel('./data/학생시험성적2.xlsx', encoding='utf-8')

# %%
df = pd.DataFrame(excel_exam_data1,)
df.to_excel('./data/학생시험성적2.xlsx', encoding='utf-8', index=False)

# %%
excel_exam_data2 = {
    '학생' : ['A', 'B', 'C', 'D', 'E'],
    '한식' : [100, 60, 70, 80, 60],
    '중식' : [70, 80, 60, 90, 100],
    '일식' : [80, 90, 100, 70, 90],
    '양식' : [70, 100, 90, 80, 80],
}
df2 = pd.DataFrame(excel_exam_data2)

# %%
excel_exam_data2 = {
    '학생' : ['A', 'B', 'C', 'D', 'E'],
    '한식' : [100, 60, 70, 80, 60],
    '중식' : [70, 80, 60, 90, 100],
    '일식' : [80, 90, 100, 70, 90],
    '양식' : [70, 100, 90, 80, 80],
}
df2 = pd.DataFrame(excel_exam_data2)
df2.to_excel('학생요리성적.xlsx', encoding='cp949', index=False)

# %%
excel_exam_data2 = {
    '학생' : ['A', 'B', 'C', 'D', 'E'],
    '한식' : [100, 60, 70, 80, 60],
    '중식' : [70, 80, 60, 90, 100],
    '일식' : [80, 90, 100, 70, 90],
    '양식' : [70, 100, 90, 80, 80],
}
df2 = pd.DataFrame(excel_exam_data2)
df2.to_excel('./data/학생요리성적.xlsx', encoding='cp949', index=False)

# %%
pd.DataFrame(columns=['A', 'B', 'C', 'D', 'E'])
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E]
# Index: []

# %%
pd.DataFrame(columns=['학생', '한식', '중식', '일식', '양식'],
             data=[['A', 'B', 'C', 'D', 'E'],
                   [100, 60, 70, 80, 60],
                   [70, 80, 60, 90, 100],
                   [80, 90, 100, 70, 90],
                   [70, 100, 90, 80, 80], ])
# Out:
#     학생   한식   중식  일식   양식
# 0    A    B    C   D    E
# 1  100   60   70  80   60
# 2   70   80   60  90  100
# 3   80   90  100  70   90
# 4   70  100   90  80   80

# %%
excel_exam_data2 = {
    '학생': ['A', 'B', 'C', 'D', 'E'],
    '한식': [100, 60, 70, 80, 60],
    '중식': [70, 80, 60, 90, 100],
    '일식': [80, 90, 100, 70, 90],
    '양식': [70, 100, 90, 80, 80],
}
df2 = pd.DataFrame(excel_exam_data2)
df2.to_excel('./data/학생요리성적.xlsx', encoding='utf-8', index=False)

# %%
df2.to_csv('./data/학생요리성적.csv', index=False)

# %%
# 1개의 excel 파일에 2개의 데이터를 각각 다른 시트에 저장

# %%
# 1개의 excel 파일에 2개의 데이터를 각각 다른 시트에 저장
# 데이터 저장 옵션

# %%
with pd.ExcelWriter('./data/학생시험성적3.xlsx', engine='xlsxwriter') as w:
    df.to_excel(w, sheet_name='일반교과목', index=False)
    df2.to_excel(w, sheet_name='교양교과목', index=False)

# %%
# 데이터 저장 옵션
# 기본 옵션 : sheet_name = 0 / index_col = 0
# 1개의 excel 파일에 2개의 데이터를 각각 다른 시트에 저장

# %%
# 엑셀파일 저장하기
excel_data_files = [
    './data/예제_데이터/담당자별_판매량_Andy사원.xlsx',
    './data/예제_데이터/담당자별_판매량_Becky사원.xlsx',
    './data/예제_데이터/담당자별_판매량_Chris사원.xlsx'
]

# %%
total_data = pd.DataFrame()
for i in excel_data_files:
    total_data.append(pd.read_excel(i))

# %%
total_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
total_data = pd.DataFrame()
for i in excel_data_files:
    total_data = total_data.append(pd.read_excel(i))

# %%
total_data
# Out:
#    제품명 담당자 지역  1분기  2분기  3분기  4분기
# 0   시계   A  가  198  123  120  137
# 1   구두   A  가  273  241  296  217
# 2  핸드백   A  가  385  316  355  331
# 0   시계   B  나  154  108  155  114
# 1   구두   B  나  200  223  213  202
# 2  핸드백   B  나  350  340  377  392
# 0   시계   C  다  168  102  149  174
# 1   구두   C  다  231  279  277  292
# 2  핸드백   C  다  365  383  308  323

# %%
total_data = pd.DataFrame()
for i in excel_data_files:
    total_data = total_data.append(pd.read_excel(i), ignore_index=True)

# %%
total_data
# Out:
#    제품명 담당자 지역  1분기  2분기  3분기  4분기
# 0   시계   A  가  198  123  120  137
# 1   구두   A  가  273  241  296  217
# 2  핸드백   A  가  385  316  355  331
# 3   시계   B  나  154  108  155  114
# 4   구두   B  나  200  223  213  202
# 5  핸드백   B  나  350  340  377  392
# 6   시계   C  다  168  102  149  174
# 7   구두   C  다  231  279  277  292
# 8  핸드백   C  다  365  383  308  323

# %%
# 실습 100개의 excel 파일 통합

from glob import glob

glob('./data/예제_data')
# Out:
# []

# %%
# 실습 100개의 excel 파일 통합

from glob import glob

glob('./data/예제_data/')
# Out:
# []

# %%
# 실습 100개의 excel 파일 통합

from glob import glob

glob("./data/예제_data/")
# Out:
# []

# %%
# 실습 100개의 excel 파일 통합

from glob import glob

glob('./data/예제_data/담당자*')
# Out:
# []

# %%
# 실습 100개의 excel 파일 통합

from glob import glob

glob('./data/예제_데이터')
# Out:
# ['./data/예제_데이터']

# %%
# 실습 100개의 excel 파일 통합

from glob import glob

glob('./data/예제_데이터/')
# Out:
# ['./data/예제_데이터/']

# %%
# 실습 100개의 excel 파일 통합

from glob import glob

glob('./data/예제_데이터/*')
# Out:
# ['./data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (10).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (11).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (12).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (13).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (14).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (15).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (16).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (17).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (18).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (19).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (2).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (20).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (21).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (22).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (23).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (24).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (25).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (26).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (27).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (28).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (29).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (3).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (30).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (31).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (32).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (33).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (4).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (5).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (6).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (7).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (8).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (9).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본.xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원.xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (10).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (11).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (12).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (13).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (14).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (15).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (16).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (17).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (18).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (19).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (2).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (20).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (21).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (22).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (23).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (24).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (25).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (26).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (27).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (28).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (29).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (3).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (30).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (31).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (32).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (33).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (4).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (5).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (6).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (7).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (8).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (9).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본.xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원.xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (10).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (11).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (12).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (13).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (14).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (15).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (16).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (17).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (18).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (19).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (2).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (20).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (21).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (22).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (23).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (24).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (25).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (26).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (27).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (28).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (29).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (3).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (30).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (31).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (32).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (33).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (4).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (5).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (6).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (7).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (8).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (9).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본.xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원.xlsx']

# %%
# 실습 100개의 excel 파일 통합
from glob import glob

excel_data_files2 = glob('./data/예제_데이터/담당자*')

# %%
len(excel_data_files2)
# Out:
# 102

# %%
excel_data_files2
# Out:
# ['./data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (10).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (11).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (12).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (13).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (14).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (15).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (16).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (17).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (18).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (19).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (2).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (20).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (21).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (22).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (23).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (24).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (25).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (26).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (27).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (28).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (29).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (3).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (30).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (31).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (32).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (33).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (4).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (5).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (6).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (7).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (8).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (9).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본.xlsx',
#  './data/예제_데이터\\담당자별_판매량_Andy사원.xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (10).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (11).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (12).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (13).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (14).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (15).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (16).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (17).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (18).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (19).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (2).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (20).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (21).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (22).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (23).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (24).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (25).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (26).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (27).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (28).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (29).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (3).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (30).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (31).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (32).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (33).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (4).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (5).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (6).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (7).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (8).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본 (9).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원 - 복사본.xlsx',
#  './data/예제_데이터\\담당자별_판매량_Becky사원.xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (10).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (11).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (12).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (13).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (14).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (15).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (16).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (17).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (18).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (19).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (2).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (20).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (21).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (22).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (23).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (24).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (25).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (26).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (27).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (28).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (29).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (3).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (30).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (31).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (32).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (33).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (4).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (5).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (6).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (7).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (8).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본 (9).xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원 - 복사본.xlsx',
#  './data/예제_데이터\\담당자별_판매량_Chris사원.xlsx']

# %%
i
# Out:
# './data/예제_데이터\\담당자별_판매량_Andy사원 - 복사본 (10).xlsx'

# %%
# 실습 100개의 excel 파일 통합
from glob import glob

excel_data_files2 = glob('./data/예제_데이터/담당자*')
total_data2 = pd.DataFrame()
for i in excel_data_files2 :
    total_data2 = total_data2.append(pd.read_excel(i), ignore_index=True)
total_data2.to_excel('./data/담당자_판매량통합.xlsx', index=False, sheet_name='판매량통합')

# %%
total_data2
# Out:
#      제품명 담당자 지역  1분기  2분기  3분기  4분기
# 0     시계   A  가  198  123  120  137
# 1     구두   A  가  273  241  296  217
# 2    핸드백   A  가  385  316  355  331
# 3     시계   A  가  198  123  120  137
# 4     구두   A  가  273  241  296  217
# ..   ...  .. ..  ...  ...  ...  ...
# 301   구두   C  다  231  279  277  292
# 302  핸드백   C  다  365  383  308  323
# 303   시계   C  다  168  102  149  174
# 304   구두   C  다  231  279  277  292
# 305  핸드백   C  다  365  383  308  323
#
# [306 rows x 7 columns]

# %%
# 파일들의 위치가 다를때 파일 통합

import sys

input_files = sys.argv[1]
output_filename = sys.argv[2]

# %%
df = pd.read_excel('./data/예제_데이터/담당자별_판매량_Andy사원.xlsx')

# %%
df
# Out:
#    제품명 담당자 지역  1분기  2분기  3분기  4분기
# 0   시계   A  가  198  123  120  137
# 1   구두   A  가  273  241  296  217
# 2  핸드백   A  가  385  316  355  331

# %%
df['제품명']
# Out:
# 0     시계
# 1     구두
# 2    핸드백
# Name: 제품명, dtype: object

# %%
df[['제품명', '1분기', '2분기', '3분기', '4분기']]
# Out:
#    제품명  1분기  2분기  3분기  4분기
# 0   시계  198  123  120  137
# 1   구두  273  241  296  217
# 2  핸드백  385  316  355  331

# %%
df
# Out:
#    제품명 담당자 지역  1분기  2분기  3분기  4분기
# 0   시계   A  가  198  123  120  137
# 1   구두   A  가  273  241  296  217
# 2  핸드백   A  가  385  316  355  331

# %%
df = pd.read_excel('./data/예제_데이터/담당자별_판매량_Andy사원.xlsx')
df[['제품명', '1분기', '2분기', '3분기', '4분기']]
# Out:
#    제품명  1분기  2분기  3분기  4분기
# 0   시계  198  123  120  137
# 1   구두  273  241  296  217
# 2  핸드백  385  316  355  331

# %%
df
# Out:
#    제품명 담당자 지역  1분기  2분기  3분기  4분기
# 0   시계   A  가  198  123  120  137
# 1   구두   A  가  273  241  296  217
# 2  핸드백   A  가  385  316  355  331

# %%
df.loc[:]
# Out:
#    제품명 담당자 지역  1분기  2분기  3분기  4분기
# 0   시계   A  가  198  123  120  137
# 1   구두   A  가  273  241  296  217
# 2  핸드백   A  가  385  316  355  331

# %%
df.loc[2:1]
# Out:
# Empty DataFrame
# Columns: [제품명, 담당자, 지역, 1분기, 2분기, 3분기, 4분기]
# Index: []

# %%
df.loc[2:]
# Out:
#    제품명 담당자 지역  1분기  2분기  3분기  4분기
# 2  핸드백   A  가  385  316  355  331

# %%
df = pd.read_excel('./data/예제_데이터/담당자별_판매량_Andy사원.xlsx')
df1 = df[['제품명', '1분기', '2분기', '3분기', '4분기']]

# %%
df1
# Out:
#    제품명  1분기  2분기  3분기  4분기
# 0   시계  198  123  120  137
# 1   구두  273  241  296  217
# 2  핸드백  385  316  355  331

# %%
df1.loc[2, '4분기']
# Out:
# 331

# %%
df1.loc[2, '4분기'] = 500
# Out:
# C:\Users\kitri\.conda\envs\py38\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df1.loc[2, '4분기'] = 500
df1
# Out:
#    제품명  1분기  2분기  3분기  4분기
# 0   시계  198  123  120  137
# 1   구두  273  241  296  217
# 2  핸드백  385  316  355  500

# %%
df1.loc[2, '4분기']
df1
# Out:
#    제품명  1분기  2분기  3분기  4분기
# 0   시계  198  123  120  137
# 1   구두  273  241  296  217
# 2  핸드백  385  316  355  500

# %%
df1.loc[2, '4분기'] = 500
df1
# Out:
# C:\Users\kitri\.conda\envs\py38\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#    제품명  1분기  2분기  3분기  4분기
# 0   시계  198  123  120  137
# 1   구두  273  241  296  217
# 2  핸드백  385  316  355  500

# %%
df1.iloc[1,3] = 750
# Out:
# C:\Users\kitri\.conda\envs\py38\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df1.iloc[1,3] = 750
df1
# Out:
#    제품명  1분기  2분기  3분기  4분기
# 0   시계  198  123  120  137
# 1   구두  273  241  750  217
# 2  핸드백  385  316  355  500

# %%
df1.loc['1','3분기'] = 750
# Out:
# C:\Users\kitri\AppData\Local\Temp/ipykernel_5736/3438882313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc['1','3분기'] = 750

# %%
df1.loc['1','3분기'] = 780

# %%
df1.loc['1','3분기'] = 780
df1
# Out:
#    제품명    1분기    2분기    3분기    4분기
# 0   시계  198.0  123.0  120.0  137.0
# 1   구두  273.0  241.0  750.0  217.0
# 2  핸드백  385.0  316.0  355.0  500.0
# 1  NaN    NaN    NaN  780.0    NaN

# %%
df1
# Out:
#    제품명    1분기    2분기    3분기    4분기
# 0   시계  198.0  123.0  120.0  137.0
# 1   구두  273.0  241.0  750.0  217.0
# 2  핸드백  385.0  316.0  355.0  500.0
# 1  NaN    NaN    NaN  780.0    NaN

# %%
df = pd.read_excel('./data/예제_데이터/담당자별_판매량_Andy사원.xlsx')
df1 = df[['제품명', '1분기', '2분기', '3분기', '4분기']]

# %%
df1.loc[2, '4분기'] = 500
df1
# Out:
# C:\Users\kitri\.conda\envs\py38\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#    제품명  1분기  2분기  3분기  4분기
# 0   시계  198  123  120  137
# 1   구두  273  241  296  217
# 2  핸드백  385  316  355  500

# %%
df1.iloc[1,3] = 750
df1
# Out:
# C:\Users\kitri\.conda\envs\py38\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#    제품명  1분기  2분기  3분기  4분기
# 0   시계  198  123  120  137
# 1   구두  273  241  750  217
# 2  핸드백  385  316  355  500

# %%
df1.loc[3, '제품명'] = '운동화'
# Out:
# C:\Users\kitri\AppData\Local\Temp/ipykernel_5736/705448525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[3, '제품명'] = '운동화'

# %%
df.loc[3, '제품명'] = '운동화'

# %%
df
# Out:
#    제품명  담당자   지역    1분기    2분기    3분기    4분기
# 0   시계    A    가  198.0  123.0  120.0  137.0
# 1   구두    A    가  273.0  241.0  296.0  217.0
# 2  핸드백    A    가  385.0  316.0  355.0  331.0
# 3  운동화  NaN  NaN    NaN    NaN    NaN    NaN

# %%
df.loc[3, '제품명'] = '운동화'
df.loc[3, '담당자'] = 'A'
df.loc[3, '1분기'] = '100'
df.loc[3, '2분기'] = '200'
df.loc[3, '3분기'] = '300'
df.loc[3, '4분기'] = '400'

# %%
df
# Out:
#    제품명 담당자   지역    1분기    2분기    3분기    4분기
# 0   시계   A    가  198.0  123.0  120.0  137.0
# 1   구두   A    가  273.0  241.0  296.0  217.0
# 2  핸드백   A    가  385.0  316.0  355.0  331.0
# 3  운동화   A  NaN    100    200    300    400

# %%
df.loc[3, '제품명'] = '운동화'
df.loc[3, '담당자'] = 'A'
df.loc[3, '1분기'] = 100
df.loc[3, '2분기'] = 200
df.loc[3, '3분기'] = 300
df.loc[3, '4분기'] = 400

# %%
df
# Out:
#    제품명 담당자   지역    1분기    2분기    3분기    4분기
# 0   시계   A    가  198.0  123.0  120.0  137.0
# 1   구두   A    가  273.0  241.0  296.0  217.0
# 2  핸드백   A    가  385.0  316.0  355.0  331.0
# 3  운동화   A  NaN    100    200    300    400

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.iloc[3,4])
# Out:
# int

# %%
type(df.iloc[2,4])
# Out:
# float

# %%
df.loc[3, '제품명'] = '운동화'
df.loc[3, '담당자'] = 'A'
df.loc[3, '1분기'] = 100.0
df.loc[3, '2분기'] = 200.0
df.loc[3, '3분기'] = 300.0
df.loc[3, '4분기'] = 400.0

# %%
type(df.iloc[3,4])
# Out:
# float

# %%
df
# Out:
#    제품명 담당자   지역    1분기    2분기    3분기    4분기
# 0   시계   A    가  198.0  123.0  120.0  137.0
# 1   구두   A    가  273.0  241.0  296.0  217.0
# 2  핸드백   A    가  385.0  316.0  355.0  331.0
# 3  운동화   A  NaN  100.0  200.0  300.0  400.0

# %%
df.loc[3, '제품명'] = '운동화'
df.loc[3, '담당자'] = 'A'
df.loc[3, '지역'] = '가'
df.loc[3, '1분기'] = 100.0
df.loc[3, '2분기'] = 200.0
df.loc[3, '3분기'] = 300.0
df.loc[3, '4분기'] = 400.0

# %%
df.iloc[2,3]
# Out:
# 385.0

# %%
df.iloc[2,3] = 385.0

# %%
df.loc[3, '제품명'] = '운동화'
df.loc[3, '담당자'] = 'A'
df.loc[3, '지역'] = '가'
df.loc[3, '1분기'] = 100.0
df.loc[3, '2분기'] = 200.0
df.loc[3, '3분기'] = 300.0
df.loc[3, '4분기'] = 400.0

# %%
df['지역'].replace('가', '구로구')
# Out:
# 0    구로구
# 1    구로구
# 2    구로구
# 3    구로구
# Name: 지역, dtype: object

# %%
df['지역'].replace('가', '구로구')
df
# Out:
#    제품명 담당자 지역    1분기    2분기    3분기    4분기
# 0   시계   A  가  198.0  123.0  120.0  137.0
# 1   구두   A  가  273.0  241.0  296.0  217.0
# 2  핸드백   A  가  385.0  316.0  355.0  331.0
# 3  운동화   A  가  100.0  200.0  300.0  400.0

# %%
df['지역'].replace('가', '구로구', inplace=True)
df
# Out:
#    제품명 담당자   지역    1분기    2분기    3분기    4분기
# 0   시계   A  구로구  198.0  123.0  120.0  137.0
# 1   구두   A  구로구  273.0  241.0  296.0  217.0
# 2  핸드백   A  구로구  385.0  316.0  355.0  331.0
# 3  운동화   A  구로구  100.0  200.0  300.0  400.0

# %%
excel_file_name = "./data/예제_데이터/담당자별_판매량_Andy사원10.xlsx"
df.to_excel(excel_file_name, index=False)

# %%
excel_file_name = "./data/예제_데이터/담당자별_판매량_Andy사원10.xlsx"
df.to_excel(excel_file_name, index=False)
glob(excel_file_name)   # 파일 생성 확인
# Out:
# ['./data/예제_데이터/담당자별_판매량_Andy사원10.xlsx']

# %%
df.loc[3]
# Out:
# 제품명      운동화
# 담당자        A
# 지역       구로구
# 1분기    100.0
# 2분기    200.0
# 3분기    300.0
# 4분기    400.0
# Name: 3, dtype: object

# %%
df.loc[1]
# Out:
# 제품명       구두
# 담당자        A
# 지역       구로구
# 1분기    273.0
# 2분기    241.0
# 3분기    296.0
# 4분기    217.0
# Name: 1, dtype: object
